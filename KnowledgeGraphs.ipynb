# %% [markdown]
# <a href="https://colab.research.google.com/github/Teasotea/BioNER-and-RD/blob/main/KnowledgeGraphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
import os
import math
import random
import csv
import sys

import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
import statistics as stats

# %%
import nltk
from nltk.tokenize import TreebankWordTokenizer as twt
import spacy
from spacy import displacy

# %%
import pickle
from google.colab import files

# %%
import bs4
import requests
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %% [markdown]
# # Load Data

# %%
with open('/content/data0.txt') as f:
      eval_article = f.read()

# %%
train_df = pd.read_csv('/content/cdr_dner_train_df.csv')
test_df = pd.read_csv('/content/cdr_dner_test_df.csv')
dev_df = pd.read_csv('/content/cdr_dner_dev_df.csv')

# %%
CID_train_df = train_df[train_df['xloc'] == "CID"].reset_index(drop=True)
DNER_train_df = train_df[train_df['xloc'] != "CID"].reset_index(drop=True)

CID_test_df = test_df[test_df['xloc'] == "CID"].reset_index(drop=True)
DNER_test_df = test_df[test_df['xloc'] != "CID"].reset_index(drop=True)

CID_dev_df = dev_df[dev_df['xloc'] == "CID"].reset_index(drop=True)
DNER_dev_df = dev_df[dev_df['xloc'] != "CID"].reset_index(drop=True)

# %%
iob_train = pd.read_csv('/content/iob_train.csv',converters={"tokens": lambda x: x.strip("[]").replace("'","").split(", "), "iob_tags": lambda x: x.strip("[]").replace("'","").split(", ")})
iob_test = pd.read_csv('/content/iob_test.csv',converters={"tokens": lambda x: x.strip("[]").replace("'","").split(", "), "iob_tags": lambda x: x.strip("[]").replace("'","").split(", ")})
iob_dev = pd.read_csv('/content/iob_dev.csv',converters={"tokens": lambda x: x.strip("[]").replace("'","").split(", "), "iob_tags": lambda x: x.strip("[]").replace("'","").split(", ")})

# %%
iob_dev
# Out:
#                                                                                                                                                                                                       tokens  \
# 0    [Tricuspid, valve, regurgitation, and, lithium, carbonate, toxicity, in, a, newborn, infant., A, newborn, with, massive, tricuspid, regurgitation, ,, atrial, flutter, ,, congestive, heart, failure...
# 1    [Phenobarbital-induced, dyskinesia, in, a, neurologically-impaired, child., A, 2-year-old, child, with, known, neurologic, impairment, developed, a, dyskinesia, soon, after, starting, phenobarbita...
# 2    [Acute, changes, of, blood, ammonia, may, predict, short-term, adverse, effects, of, valproic, acid., Valproic, acid, (, VPA, ), was, given, to, 24, epileptic, patients, who, were, already, being,...
# 3    [Effects, of, calcitonin, on, rat, extrapyramidal, motor, system, :, behavioral, and, biochemical, data., The, effects, of, i.v.c., injection, of, human, and, salmon, calcitonin, on, biochemical, ...
# 4    [Development, of, isoproterenol-induced, cardiac, hypertrophy., The, development, of, cardiac, hypertrophy, was, studied, in, adult, female, Wistar, rats, following, daily, subcutaneous, injection...
# ..                                                                                                                                                                                                       ...
# 487  [Reversible, cerebral, lesions, associated, with, tiazofurin, usage, :, MR, demonstration., Tiazofurin, is, an, experimental, chemotherapeutic, agent, currently, undergoing, clinical, evaluation.,...
# 488  [Antagonism, of, diazepam-induced, sedative, effects, by, Ro15-1788, in, patients, after, surgery, under, lumbar, epidural, block., A, double-blind, placebo-controlled, investigation, of, efficacy...
# 489  [Enhanced, stimulus-induced, neurotransmitter, overflow, in, epinephrine-induced, hypertensive, rats, is, not, mediated, by, prejunctional, beta-adrenoceptor, activation., The, present, study, exa...
# 490  [Ocular, manifestations, of, juvenile, rheumatoid, arthritis., We, followed, 210, cases, of, juvenile, rheumatoid, arthritis, closely, for, eleven, years., Thirty-six, of, the, 210, patients, (, 1...
# 491  [Water, intoxication, associated, with, oxytocin, administration, during, saline-induced, abortion., Four, cases, of, water, intoxication, in, connection, with, oxytocin, administration, during, s...
#
#                                                                                                                                                                                                     iob_tags
# 0    [B-Disease, I-Disease, I-Disease, O, B-Chemical, I-Chemical, B-Disease, O, O, O, O, O, O, O, O, B-Disease, I-Disease, O, B-Disease, I-Disease, O, B-Disease, I-Disease, I-Disease, O, O, O, O, O, B-...
# 1    [B-Chemical, B-Disease, O, O, B-Disease, O, O, O, O, O, O, B-Disease, I-Disease, O, O, B-Disease, O, O, O, B-Chemical, O, O, B-Disease, O, O, O, B-Disease, I-Disease, O, O, O, O, O, O, O, O, B-Che...
# 2    [O, O, O, O, B-Chemical, O, O, O, O, O, O, B-Chemical, O, B-Chemical, I-Chemical, O, B-Chemical, O, O, O, O, O, B-Disease, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-Chemical, O, O, O, O, O, O...
# 3    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-Chemical, B-Disease, O, O, O, O, O, B-Chemical, B-Di...
# 4    [O, O, B-Chemical, B-Disease, O, O, O, O, B-Disease, I-Disease, O, O, O, O, O, O, O, O, O, O, O, O, B-Chemical, O, B-Chemical, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# ..                                                                                                                                                                                                       ...
# 487  [O, B-Disease, I-Disease, O, O, B-Chemical, O, O, O, O, B-Chemical, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-Disease, I-Disease, O, O, O, O, O, O, O, O, O, O, O, O, O, O...
# 488  [O, O, B-Chemical, O, O, O, B-Chemical, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-Chemical, O, O, O, O, O, B-Chemical, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 489  [O, O, O, O, O, B-Chemical, B-Disease, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-Chemical, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-Chemical, O, O, B...
# 490  [O, O, O, B-Disease, I-Disease, O, O, O, O, O, O, B-Disease, I-Disease, I-Disease, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-Disease, B-Disease, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O...
# 491  [B-Disease, I-Disease, O, O, B-Chemical, O, O, O, B-Disease, O, O, O, B-Disease, I-Disease, O, O, O, B-Chemical, O, O, O, B-Disease, O, O, O, O, O, B-Disease, I-Disease, O, O, O, O, O, O, O, B-Che...
#
# [492 rows x 2 columns]

# %% [markdown]
# # BERT-sklearn

# %%
# !git clone -b master https://github.com/charles9n/bert-sklearn
# !cd bert-sklearn; pip install .
import os
os.chdir("bert-sklearn")
print(os.listdir())

# %%
# !pip install --upgrade botocore==1.23.26
# !pip install --upgrade urllib3==1.22.0

# %%
# !pip install --upgrade sagemaker

# %%
from bert_sklearn import BertTokenClassifier
from bert_sklearn import load_model

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

# %%
train = iob_train.append(iob_dev, ignore_index=True)
train = train.reset_index(drop = True)
print("Train and dev data: %d sentences, %d tokens"%(len(train), len(flatten(train.tokens.tolist()))))
print("Test data: %d sentences, %d tokens"%(len(iob_test), len(flatten(iob_test.tokens))))

# %%
X_train, y_train = train.tokens, train.iob_tags
X_test, y_test = iob_test.tokens, iob_test.iob_tags

# %%
y_train

# %%
label_list = list(np.unique(flatten(y_train)))
print("\nNER tags:", label_list)

# %%
train.head()

# %% [markdown]
# ### Finetune SciBERT
#
# 1) Use `'scibert-scivocab-cased'` model. [GitHub](https://github.com/allenai/scibert), [paper](https://arxiv.org/pdf/1903.10676.pdf)
#
# 2) Set the **`ignore_label`** =`['O']`. Exclude the non named entities.
#
# 3) Set the **` max_seq_len`** = 256 - high enough to cover lengths of the token lists

# %%
# %%time
scibert_model = BertTokenClassifier('scibert-scivocab-cased',
                            max_seq_length=64,
                            epochs=3,
                            gradient_accumulation_steps=2,
                            learning_rate=3e-5,
                            train_batch_size=16,
                            eval_batch_size=16,
                            validation_fraction=0.,                            
                            label_list=label_list,
                            ignore_label=['O'])



scibert_model.fit(X_train, y_train)

# %%
scibert_f1_test = scibert_model.score(X_test, y_test,'macro')
print("Test f1: %0.02f"%(scibert_f1_test))

# %%
scibert_y_preds = scibert_model.predict(X_test)
print(classification_report(flatten(y_test), flatten(scibert_y_preds)))

# %%
iter_zip = zip(flatten(X_test),flatten(y_test),flatten(scibert_y_preds))
preds = [" ".join([token, y, y_pred]) for token, y, y_pred in iter_zip]
with open("preds.txt",'w') as f:
    for x in preds:
        f.write(str(x)+'\n') 

# !perl ./other_examples/conlleval.pl < preds.txt
# !rm preds.txt

# %%
num = 28
tokens = X_test[num]
labels = y_test[num]
scibert_preds  = scibert_y_preds[num]

# %%
data = {"token": tokens,"label": labels, "scibert": scibert_preds}
df=pd.DataFrame(data=data)
df.head(50)

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# from sklearn.model_selection import GridSearchCV

# params = {'epochs':[3, 4], 'learning_rate':[2e-5, 3e-5, 5e-5]}

# scibert_clf = GridSearchCV(BertTokenClassifier('scibert-scivocab-cased',
#                             max_seq_length=256,
#                             gradient_accumulation_steps=2,
#                             train_batch_size=16,
#                             eval_batch_size=16,
#                             validation_fraction=0.,                            
#                             label_list=label_list,
#                             ignore_label=['O']), 
#                    params,
#                    verbose=True)

# scibert_clf.fit(X_train ,y_train)

# %% [markdown]
# # Results of DNER task with SciBERT

# %%
eval_data = pd.Series(eval_article.split('\n'))
tokenized_eval_data = eval_data.apply(lambda x:list(twt().tokenize(x)))
tokenized_eval_data
# Out:
# 0      [Transductional, analysis, was, applied, to, the, Pseudomonas, aeruginosa, mutant, PAO14, (, hnc-1, ), ., This, mutant, can, utilize, L-histidinol, as, sole, source, of, carbon, and, nitrogen, and...
# 1      [Bacteriocins, produced, by, six, strains, of, Rhizobium, trifolii, were, found, to, be, of, the, relatively, low, molecular, weight, ,, non-phage, type., The, molecular, weights, ranged, from, ap...
# 2      [The, gamma, haemolysin, of, Staphylococcus, aureus, \'Smith, 5R\, ', was, produced, on, Dolman-Wilson, agar, overlain, with, cellophane., Maximal, yields, of, crude, lysin, with, titres, of, 2000...
# 3      [Arginine, and, methionine, transport, by, Aspergillus, nidulans, mycelium, was, investigated., A, single, uptake, system, is, responsible, for, the, transport, of, arginine, ,, lysine, and, ornit...
# 4      [Aphids, transmitted, poly-L-ornithine, (, PLO, ), -treated, tobacco, mosaic, virus, (, TMV, ), when, given, acquistion, and, inoculation, access, periods, as, brief, as, 30, s, and, 2, min, ,, re...
#                                                                                                         ...
# 96     [Most-probable-number, (, MPN, ), and, membrane, filtration, (, mF, ), techniques, were, evaluated, with, respect, to, selectivity, ,, sensitivity, ,, and, efficiency, in, recovering, Pseudomonas,...
# 97     [The, relationship, between, muscle, surface, pH, (, pHM, ), and, the, arterial-venous, oxygen, content, difference, (, AVO2D, ), was, studied, in, 4, patients, undergoing, reconstructive, arteria...
# 98     [The, specificity, of, Ca++, for, the, interaction, of, beta, adrenergic, agonists, with, their, receptors, in, rabbit, right, atrial, muscle, was, evaluated., This, was, accomplished, by, substit...
# 99     [The, action, of, a, number, of, compounds, able, to, react, with, thiols, was, tested, on, guinea-pig, hearts, perfused, at, constant, pressure., The, SH, reagents, used, were, NaNO2, ,, oxidized...
# 100                                                                                                                                                                                                         []
# Length: 101, dtype: object

# %%
# # # save the model to disk
# # scibert_model_file = '/content/scibert_model.sav'
# # pickle.dump(scibert_model, open(scibert_model_file, 'wb'))

# # load the model from disk
# loaded_model = pickle.load(open(scibert_model_file, 'r'))
# # loaded_model = pd.read_pickle(open(scibert_model_file, 'r'))

# %%
# result = loaded_model.score(X_test, y_test)

# %%
# files.download('scibert_model.sav')

# %%
eval_predicts_scibert = scibert_model.predict(tokenized_eval_data)

# %%
print(eval_predicts_scibert[4])

# %%
print(len(eval_predicts_scibert), len(eval_data.tolist()))

# %%
def locate_entities(text, annots):
  loc_list = []
  span_list = list(twt().span_tokenize(text))
  for annotation, loc in zip(annots, span_list):
    if annotation != 'O':
      loc = (loc[0], loc[1], str(annotation))
      loc_list.append(loc)
  return loc_list

# %%
eval_data_entities = [locate_entities(x,y) for x, y in zip(eval_data.tolist(), eval_predicts_scibert)]
eval_data_entities[99]

# %%
def display_entities(eval_data, num):
  if len(eval_data_entities[num]) == 0:
    return eval_data
  scibert_annot_data = [(eval_data.tolist()[num],
  {'entities': eval_data_entities[num]})]
  options = {"ents": ['B-Chemical', 'B-Disease','I-Chemical', 'I-Disease'], "colors": {'B-Chemical': "#85C1E9", "B-Disease": "#ff6961", 'I-Chemical': "#85C1E9", "I-Disease": "#ff6961"}}
  nlp = spacy.blank('en')
  raw_text = scibert_annot_data[0][0]
  doc = nlp.make_doc(raw_text)
  spans = scibert_annot_data[0][1]["entities"]
  ents = []
  for span_start, span_end, label in spans:
    ent = doc.char_span(span_start, span_end, label=label)
    if ent is None:
        continue
    ents.append(ent)
  doc.ents = ents
  displacy.render(doc, style="ent",options=options, jupyter=True)

# %%
display_entities(eval_data, 99)

# %%
for i in range(5,15):
  display_entities(eval_data, i)

# %% [markdown]
# # Relation Extraction

# %%
CID_train_df["text"] = CID_train_df.apply(lambda x: x['title_source_text']+ ' '+x['source_text'], axis = 1)
CID_test_df["text"] = CID_test_df.apply(lambda x: x['title_source_text']+ ' '+x['source_text'], axis = 1)
CID_dev_df["text"] = CID_dev_df.apply(lambda x: x['title_source_text']+ ' '+x['source_text'], axis = 1)

CID_train_df = CID_train_df.drop(columns = ['entity', 'name_id', 'title_source_text', 'source_text', 'xloc'])
CID_test_df = CID_test_df.drop(columns = ['entity', 'name_id', 'title_source_text', 'source_text', 'xloc'])
CID_dev_df = CID_dev_df.drop(columns = ['entity', 'name_id', 'title_source_text', 'source_text', 'xloc'])

# %%
CID_train_df = CID_train_df[CID_train_df['name'].str.startswith('D') & CID_train_df['yloc'].str.startswith('D')]
CID_test_df = CID_test_df[CID_test_df['name'].str.startswith('D') & CID_test_df['yloc'].str.startswith('D')]
CID_dev_df = CID_dev_df[CID_dev_df['name'].str.startswith('D') & CID_dev_df['yloc'].str.startswith('D')]

# %%
CID_train_df.head()
# Out:
#    text_id     yloc     name  \
# 0   354896  D008012  D006323
# 1   435349  D013390  D005207
# 2   603022  D012601  D062787
# 3  1378968  D008094  D006973
# 4  1378968  D008094  D011507
#
#                                                                                                                                                                                                       text
# 0  Lidocaine-induced cardiac asystole. Intravenous administration of a single 50-mg bolus of lidocaine in a 67-year-old man resulted in profound depression of the activity of the sinoatrial and atrio...
# 1  Suxamethonium infusion rate and observed fasciculations. A dose-response study. Suxamethonium chloride (Sch) was administered i.v. to 36 adult males at six rates: 0.25 mg s-1 to 20 mg s-1. The inf...
# 2  Galanthamine hydrobromide, a longer acting anticholinesterase drug, in the treatment of the central effects of scopolamine (Hyoscine). Galanthamine hydrobromide, an anticholinesterase drug capable...
# 3  Effects of uninephrectomy and high protein feeding on lithium-induced chronic renal failure in rats. Rats with lithium-induced nephropathy were subjected to high protein (HP) feeding, uninephrecto...
# 4  Effects of uninephrectomy and high protein feeding on lithium-induced chronic renal failure in rats. Rats with lithium-induced nephropathy were subjected to high protein (HP) feeding, uninephrecto...

# %%
DNER_train_df = DNER_train_df[DNER_train_df['name_id'].str.startswith('D') == True]
DNER_test_df = DNER_test_df[DNER_test_df['name_id'].str.startswith('D') == True]
DNER_dev_df = DNER_dev_df[DNER_dev_df['name_id'].str.startswith('D') == True]

# %%
test_names_df = pd.DataFrame(zip(DNER_train_df["name_id"].unique(), DNER_train_df['name'].unique()), columns=["name_id", "name"])

# %%
test_names_df.head()
# Out:
#    name_id              name
# 0  D009270          Naloxone
# 1  D003000         clonidine
# 2  D006973      hypertensive
# 3  D007022       hypotensive
# 4  D008750  alpha-methyldopa

# %%
DNER_train_df = DNER_train_df[DNER_train_df['xloc'].str.isnumeric() & DNER_train_df['yloc'].str.isnumeric()]
DNER_test_df = DNER_test_df[DNER_test_df['xloc'].str.isnumeric() & DNER_test_df['yloc'].str.isnumeric()]
DNER_dev_df = DNER_dev_df[DNER_dev_df['xloc'].str.isnumeric() & DNER_dev_df['yloc'].str.isnumeric()]

DNER_train_df = DNER_train_df.astype({"xloc": int, "yloc": int}, errors='raise')
DNER_test_df = DNER_test_df.astype({"xloc": int, "yloc": int}, errors='raise')
DNER_dev_df = DNER_dev_df.astype({"xloc": int, "yloc": int}, errors='raise')

DNER_train_df["text"] = DNER_train_df.apply(lambda x: x['title_source_text']+ ' '+x['source_text'], axis = 1)
DNER_train_df["loc"] = DNER_train_df.apply(lambda x: tuple((x['xloc'],x['yloc'])), axis = 1)

DNER_test_df['text'] = DNER_test_df.apply(lambda x: x['title_source_text']+ ' '+x['source_text'], axis = 1)
DNER_test_df["loc"] = DNER_test_df.apply(lambda x: tuple((x['xloc'],x['yloc'])), axis = 1)

DNER_dev_df['text'] = DNER_dev_df.apply(lambda x: x['title_source_text']+ ' '+x['source_text'], axis = 1)
DNER_dev_df["loc"] = DNER_dev_df.apply(lambda x: tuple((x['xloc'],x['yloc'])), axis = 1)

# %%
train_data_text_unp = pd.DataFrame(DNER_train_df["text"].unique(), columns=["sent"])
train_data_text_unp['tokens'] = train_data_text_unp.sent.apply(lambda x: list(twt().tokenize(x)))

test_data_text_unp = pd.DataFrame(DNER_test_df["text"].unique(), columns=["sent"])
test_data_text_unp['tokens'] = test_data_text_unp.sent.apply(lambda x: list(twt().tokenize(x)))

dev_data_text_unp = pd.DataFrame(DNER_dev_df["text"].unique(), columns=["sent"])
dev_data_text_unp['tokens'] = dev_data_text_unp.sent.apply(lambda x: list(twt().tokenize(x)))

# %%
def get_items( source_df, item="entity"):
  items_by_text = []
  for i in source_df["text"].unique():
    items_list = source_df[source_df["text"] == i][item].tolist()
    items_by_text.append(items_list)
  return items_by_text

def extend_df(df, source_d = DNER_train_df):
  df['entities'] = get_items(source_d,item="entity")
  df['names'] = get_items(source_d,item="name")
  df['loc'] = get_items(source_d,item="loc")
  df['name_ids'] = get_items(source_d,item="name_id")
  return df

# %%
train_data_text_unp = extend_df(train_data_text_unp, source_d = DNER_train_df)
test_data_text_unp = extend_df(test_data_text_unp, source_d = DNER_test_df)
dev_data_text_unp = extend_df(dev_data_text_unp, source_d = DNER_dev_df)

# %%
unique_train_data = train_data_text_unp['sent']
# Out:
# 0      Naloxone reverses the antihypertensive effect of clonidine. In unanesthetized, spontaneously hypertensive rats the decrease in blood pressure and heart rate produced by intravenous clonidine, 5 to...
# 1      Lidocaine-induced cardiac asystole. Intravenous administration of a single 50-mg bolus of lidocaine in a 67-year-old man resulted in profound depression of the activity of the sinoatrial and atrio...
# 2      Suxamethonium infusion rate and observed fasciculations. A dose-response study. Suxamethonium chloride (Sch) was administered i.v. to 36 adult males at six rates: 0.25 mg s-1 to 20 mg s-1. The inf...
# 3      Galanthamine hydrobromide, a longer acting anticholinesterase drug, in the treatment of the central effects of scopolamine (Hyoscine). Galanthamine hydrobromide, an anticholinesterase drug capable...
# 4      Effects of uninephrectomy and high protein feeding on lithium-induced chronic renal failure in rats. Rats with lithium-induced nephropathy were subjected to high protein (HP) feeding, uninephrecto...
#                                                                                                         ...
# 484    Visual hallucinations associated with zonisamide. Zonisamide is a broad-spectrum antiepileptic drug used to treat various types of seizures. Although visual hallucinations have not been reported a...
# 485    GLEPP1 receptor tyrosine phosphatase (Ptpro) in rat PAN nephrosis. A marker of acute podocyte injury. Glomerular epithelial protein 1 (GLEPP1) is a podocyte receptor membrane protein tyrosine phos...
# 486    Ticlopidine-induced aplastic anemia: report of three Chinese patients and review of the literature. In this study, three Chinese patients with ticlopidine-induced aplastic anemia were reported and...
# 487    Facilitation of memory retrieval by pre-test morphine and its state dependency in the step-through type passive avoidance learning test in mice. Amnesia produced by scopolamine and cycloheximide w...
# 488    Test conditions influence the response to a drug challenge in rodents. These studies were conducted to examine the differential response to a drug challenge under varied experimental test conditio...
# Name: sent, Length: 489, dtype: object

# %%
doc = nlp(unique_train_data.iloc[0])
for tok in doc:
  print(tok.text, "...", tok.dep_)
  break
# Out:
# Naloxone ... nsubj

# %%
def get_entities(sent):
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  for tok in nlp(sent):
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text

  return [ent1.strip(), ent2.strip()]

# %%
print(get_entities(unique_train_data.iloc[0]))
print(get_entities(unique_train_data.iloc[5]))
print(get_entities(unique_train_data.iloc[14]))
# Out:
# ['functional receptor antagonism', 'sympathetic alpha tone']
# ['role', 'treatment']
# ['labetalol', 'advantages']

# %%
entity_pairs = []

for i in tqdm(unique_train_data):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 489/489 [00:31<00:00, 15.31it/s]

# %%
entity_pairs[46:57]
# Out:
# [['clinicians', 'unknown  origin'],
#  ['widespread  triad', 'beta lactam antibiotics'],
#  ['carefully side effects', 'particular  patient'],
#  ['antithrombosis', 'mainly antiplatelet aggregation activities'],
#  ['New chemotherapy combinations', 'advanced  NSCLC'],
#  ['apparently calcification they', 'calcification sites'],
#  ['hyperthymic  who', 'greater mood switches'],
#  ['high guarana health case', 'such  products'],
#  ['2 respiratory cases', 'continuous dilatation mimicking fentanyl'],
#  ['cumulative  HAART', 'LA transgenic mice'],
#  ['oral  they', 'prothrombotic  mutation']]

# %%
sent_tokenized_eval_data = eval_data.apply(lambda x:x.split('. '))
sent_tokenized_eval_data.iloc[2]
# Out:
# ["The gamma haemolysin of Staphylococcus aureus \\'Smith 5R\\' was produced on Dolman-Wilson agar overlain with cellophane",
#  'Maximal yields of crude lysin with titres of 2000 to 4000 haemolytic units/ml were obtained within 24 h at 37 degrees C in 10% (v/v) CO2 in air, on medium adjusted to pH 7-0',
#  'The crude lysin was purified 2700-fold (with 75% recovery) by ultrafiltration, gel filtration and ammonium sulphate fractionation',
#  'The specific activity of the lysin was 10(5) haemolytic units/mg protein after the dialysed active precipitate was extracted with NaCl and reprecipitated with ammonium sulphate',
#  'Purified gamma lysin was homogeneous by disc electrophoresis and immunoelectrophoresis.']

# %%
sent_tokenized_eval_data = pd.DataFrame(sent_tokenized_eval_data, columns= ["paragraph"])

# %%
sent_tokenized_eval_data['entity pairs'] = sent_tokenized_eval_data["paragraph"].apply(lambda x: [get_entities(i) for i in x])

# %%
sent_tokenized_eval_data
# Out:
#                                                                                                                                                                                                    paragraph  \
# 0    [Transductional analysis was applied to the Pseudomonas aeruginosa mutant PAO14 (hnc-1), This mutant can utilize L-histidinol as sole source of carbon and nitrogen and has a 60-fold increased hist...
# 1    [Bacteriocins produced by six strains of Rhizobium trifolii were found to be of the relatively low molecular weight, non-phage type, The molecular weights ranged from approximately 1-8 X 105 to 2-...
# 2    [The gamma haemolysin of Staphylococcus aureus \'Smith 5R\' was produced on Dolman-Wilson agar overlain with cellophane, Maximal yields of crude lysin with titres of 2000 to 4000 haemolytic units/...
# 3    [Arginine and methionine transport by Aspergillus nidulans mycelium was investigated, A single uptake system is responsible for the transport of arginine, lysine and ornithine, Transport is energy...
# 4    [Aphids transmitted poly-L-ornithine (PLO)-treated tobacco mosaic virus (TMV) when given acquistion and inoculation access periods as brief as 30 s and 2 min, respectively; the ability to transmit...
# ..                                                                                                                                                                                                       ...
# 96   [Most-probable-number (MPN) and membrane filtration (mF) techniques were evaluated with respect to selectivity, sensitivity, and efficiency in recovering Pseudomonas aeruginosa strains in hospital...
# 97   [The relationship between muscle surface pH (pHM) and the arterial-venous oxygen content difference (AVO2D) was studied in 4 patients undergoing reconstructive arterial surgery and in 6 patients u...
# 98   [The specificity of Ca++ for the interaction of beta adrenergic agonists with their receptors in rabbit right atrial muscle was evaluated, This was accomplished by substituting Ca++ by an equimola...
# 99   [The action of a number of compounds able to react with thiols was tested on guinea-pig hearts perfused at constant pressure, The SH reagents used were NaNO2, oxidized glutathione, cystamine, diam...
# 100                                                                                                                                                                                                       []
#
#                                                                                                                                                                                                 entity pairs
# 0    [[Transductional  analysis, aeruginosa mutant PAO14], [mutant, HDH  content], [where  hnc-1, histidine locus biosynthesis], [at group IV which, structural  HDH], [genetic hnc-1 mutation, structura...
# 1    [[Bacteriocins, phage Rhizobium type], [molecular  weights, 1  X], [All, proteolytic protein enzymes], [They, DNAase], [six  bacteriocins, sensitive activity R], [, sensitive  bacteria], [Bacterio...
# 2    [[gamma haemolysin, Dolman Wilson cellophane], [haemolytic  ml, medium degrees pH], [crude  lysin, 75 % ultrafiltration], [active  precipitate, ammonium sulphate], [Purified gamma lysin, disc elec...
# 3    [[Arginine, Aspergillus nidulans mycelium], [single uptake system, arginine], [Transport, basic amino acids], [12  Ki, ornithine], [wt  transport, azide], [Neutral amnio acids, specifically methio...
# 4    [[respectively access ability, 90  min], [Aphids, virus], [Transmission, nonpersistent  viruses], [, well KCl concentration], [which, ml  TMV], [, ], [, ], [similar  mixture, transmission], [, ], ...
# ..                                                                                                                                                                                                       ...
# 96   [[mF membrane techniques, hospital fluids], [, occurring  P], [aeruginosa, microbial Standard Methods contamiants], [, unknown  P], [aeruginosa strains, ], [mPA MPN agars, mF assays], [Statistical...
# 97                                                     [[relationship, normovolemic oxygen content hemodilution], [, aortic inverse clamping], [, also inverse hemodilution], [pHM, reliable tissue AVO2D.]]
# 98   [[atrial  muscle, adrenergic  rabbit], [This, equimolar  Sr++], [which, electrical  Ca++], [10(-7 Sr++-containing medium, 10(-7  Ca++-containing], [clearly  Sr++, cardiac  muscle], [Also  norepine...
# 99   [[action, constant guinea pig pressure], [glutathione, ], [SH that, effect], [other SH reagents, coronary  flow], [oxidized, heart rate], [completely oxygen increase, coronary  flow], [Difluorodin...
# 100                                                                                                                                                                                                   [[, ]]
#
# [101 rows x 2 columns]

# %%
def get_relation(sent):
  matcher = Matcher(nlp.vocab)
  patterns = [[{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}]]

  matcher.add("matching_1", patterns) 
  doc = nlp(sent)
  matches = matcher(doc)
  if len(matches)>0:
    k = len(matches) - 1
    span = doc[matches[k][1]:matches[k][2]] 
  else: return ''
  return(span.text)

# %%
get_relation("John completed the task")
# Out:
# 'completed'

# %%
sent_tokenized_eval_data['relations'] = sent_tokenized_eval_data["paragraph"].apply(lambda x: [get_relation(i) for i in x])

# %%
sent_tokenized_eval_data.head(50)
# Out:
#                                                                                                                                                                                                   paragraph  \
# 0   [Transductional analysis was applied to the Pseudomonas aeruginosa mutant PAO14 (hnc-1), This mutant can utilize L-histidinol as sole source of carbon and nitrogen and has a 60-fold increased hist...
# 1   [Bacteriocins produced by six strains of Rhizobium trifolii were found to be of the relatively low molecular weight, non-phage type, The molecular weights ranged from approximately 1-8 X 105 to 2-...
# 2   [The gamma haemolysin of Staphylococcus aureus \'Smith 5R\' was produced on Dolman-Wilson agar overlain with cellophane, Maximal yields of crude lysin with titres of 2000 to 4000 haemolytic units/...
# 3   [Arginine and methionine transport by Aspergillus nidulans mycelium was investigated, A single uptake system is responsible for the transport of arginine, lysine and ornithine, Transport is energy...
# 4   [Aphids transmitted poly-L-ornithine (PLO)-treated tobacco mosaic virus (TMV) when given acquistion and inoculation access periods as brief as 30 s and 2 min, respectively; the ability to transmit...
# 5   [It has been shown that particles of Vi bacteriophage III catalyse deacetylation of O-acetyl pectic (polygalacturonic) acid, a structural analogue of Vi polysaccharide (Vi antigen), Using this sub...
# 6   [The authors measured regional cerebral 133xenon (133Xe) blood flow (rCBF), intraventricular pressure (IVP), cerebrospinal fluid (CSF) pH and lactate, systemic arterial blood pressure (SAP), and a...
# 7   [Deans of Nursing who choose to be administrators of the Health Sciences may very well enhance Nursing programs by facilitating the nursing faculty to become leaders through offering service cours...
# 8   [A basal diet or a basal diet plus 1% of cholesterol and 0.33% cholic acid was fed to rats for varying lengths of time and (1) the activities of liver phosphoenolpyruvate-carboxykinase (PEP-CK), t...
# 9   [TTP accelerated ATP-induced superprecipitation of actomyosin in as low a concentration as 30 muM and decreased light scattering by actomyosin, These effects could also be observed in the same way...
# 10  [The effects of pancuronium bromide infusion on the uptake and release of [14C] noradrenaline (14C-NA) by the isolated, perfused rat heart and on the chronotropic and inotropic activity of the iso...
# 11  [1, Electrical and mechanical activities of the longtitudinal muscle of the dog antrum were recorded with the double sucrose-gap technique, 2, The muscle exhibited spontaneous action potentials wh...
# 12  [The internal pH of crab muscle fibres was measured using recessed-tip pH-sensitive micro-electrodes, Immediately following electrode penetration the mean internal pH was 7-21 +/- 0-02 (S.E, of me...
# 13  [Oviducal fluid was collected by cannulation from four cows and by irrigation from fifteen slaughtered cows, The proteins in the fluid were examined by polyacrylamide gel electrophoresis at pH 4-5...
# 14  [Approximately 1 week was required to stabilize the extragonadal sperm reserves in stallions ejaculated daily for 10 weeks, The true daily sperm output of a stallion was equal to the mean daily sp...
# 15  [When a solution containing gly-N-pa and imidazole is evaporated to dryness and then maintained at a temperature between 65 degrees C and 100 degrees C, high yields of AppA and obligoglycines are ...
# 16  [Comparative data on quaternary structure, cooperativity, Bohr effect and regulation by organic phosphates are reviewed for vertebrate hemoglobins, A phylogeny of hemoglobin function in the verteb...
# 17  [Imidazole catalysis of phenylalanyl transfer from phenylalanine adenylate anhydride to the hydroxyl groups of homopolyribonucleotides was investigated as a chemical model of the biochemical amino...
# 18  [A three-step treatment plan incorporating adoptive immunotherapy and chemoradiotherapy was used to treat AKR (H-2k) mice bearing spontaneous leukemia-lymphoma (SLL), 1) Leukemic mice were treated...
# 19  [Chicken embryo fibroblasts infected with the nononcogenic herpesvirus of turkeys (HVT) displayed an increased rate of glucose uptake, a pronounced alteration of the pH of the medium, and an incre...
# 20  [When a 203Ng(NO3)2 solution was kept at 25 degrees C in glass or polypropylene containers, 50 and 80% of original radioactivity was adsorbed to the containers\' walls after 1 and 4 days, respecti...
# 21  [The properties of the hyperpolarization-activated sarcolemmal slow conductance increase in frog sartorius muscle fibers have been investigated using ethylenediaminetetraacetic acid disodium salt ...
# 22  [This study examines the renal response to moderate hyperventilation in healthy man, Eight men hyperventilated for 26 hr (PaCO2 approximately 30 to 32 mm Hg) in normoxia (barometric pressure, PB a...
# 23  [By animal experiments and clinically we could prove that isoglaucon instillation caused the decrease in IOP due to both increase in outflow and reduction of humor secretion; the IOP decrease and ...
# 24  [Mosquito-borne arboviruses are prevalent throughout subarctic regions of Canada and Alaska, principally in the boreal forest extending between latitudes 53 and 66 degrees N, but they have been id...
# 25  [The nucleocapsid of the Semliki Forest virus is composed of 34% RNA and 66% protein, or one RNA and about 240 capsid protein molecules, The particle is spherical, with a diameter of 38--39 nm, If...
# 26  [An association between viral hepatitis and two rheumatic disease syndromes has been observed, Twenty-nine patients manifested a transient polyarthritis, sometimes associated with a rash (Group I)...
# 27  [Rhodopseudomonas palustris, Rh, viridis, Rh, acidophila, and Rhodomicrobium vanniellii grow on media containing ethanol, n-propanol, and n-butanol, The highest amount of lower alcohols is utilize...
# 28  [Mycobacterium lacticolum 121 grows and synthesizes exopolysaccharide at the initial values of pH of the medium from 5.0 to 11.5, The accumulation of biomass is maximal (10 to 12 gram/litre) at pH...
# 29  [Chitinolytic microorganisms isolated from forest soil and from healthy gypsy moth larvae (Porthetria dispar (L.) were screened for their ability to lyse Trichophyton rubrum mycelia, A few of thes...
# 30  [The influence of some drugs on the effect of morphine on the threshold pressure required to elicit peristalsis in the guinea pig ileum in situ was studied, in order to test the hypothesis that th...
# 31  [In perifused isolated pancreatic islets alpha-ketoisocaproic acid (KIC) or alpha-ketocaproic acid (KC) induced a high insulin secretion rate and a steep increase of the fluorescence of reduced py...
# 32  [The nerve growth factor (NGF) subunit of 7S NGF was isolated by chromatography at high pH on QAE-Sephadex, It has the same specific NGF activity as betaNGF isolated at acid pH, showing that this ...
# 33  [The major protein in beta nerve growth factor preparations, beta1NGF, is a dimer in which both peptide chains have COOH-terminal arginine residues, Digestion of beta1NGF with carboxypeptidase B p...
# 34  [The effects of ritodrine hydrochloride were evaluated in 25 toxemic patients in active labor utilizing continuous electronic monitoring of fetal and maternal cardiovascular systems and uterine ac...
# 35  [Jovian plants have enviroments apparently suitable for the evolution of life, but nevertheless, present severe challenges to organisms, One such challenge arises from the presence of ammonia, Amm...
# 36  [Gamma-Glutamyltranspeptidase (GGTP) activity was studied in livers of rats submitted to an end-to-side portacaval shunt (PCS) and in developing animals, To correlate the evolution of the enzymati...
# 37  [Mucocutaneous lymph node syndrome (MCLS) is a newly recognized disease characterized by fever persisting for more than 5 days, an erythematous skin eruption, conjunctival congestion, dry red fiss...
# 38  [Lung slices from term fetal rats were incubated in vitro at various pH values and the rates of the two de novo pathways for lecithin biosynthesis were determined by measuring the conversion of ei...
# 39  [An ATPase stimulated by HCO -  ions and other oxybases and inhibited by SCN- has been found in main excretory duct of rat submaxillary gland, a tissue, capable of actively secreting HCO - 3 ions,...
# 40  [The ventilatory responses, blood gases and acid-base status to intravenous injections of KCN and doxapram hydrochloride were studied in anesthetized dogs during normothermia and at two levels of ...
# 41  [The ventilatory responses, blood gases and acid-base status to intravenous injections of KCN and doxapram hydrochloride were studied in anesthetized dogs during normothermia and thermally induced...
# 42  [The effects of alpha, alpha1-dipyridyl (DP) on noradrenaline (NA), dopamine (DA) and 5-hydroxytryptamine (5-HT) levels in rat and mouse brain and on dopamine-beta-hydroxylase (DbetaH) activity in...
# 43  [The molecular mechanism of the Bohr effect is explained according to the molecular model proposed by Perutz et al, The Bohr effect is due to changes in the pK of specific carboxyl and amino group...
# 44  [In vitro, the affinity of Hb for O2 depends on pH and capnia by the intermediate of the 2-3 DPG level, the concentration of which lowers in the case of acidosis and hypercapnia, Thus, an increase...
# 45  [The purpose of the study was to determine optimal pH values for the enzymic activity of the fungi Trichothecium roseum and Aspergillus niger hydrolyzing nonstarch polysaccharides of barley and di...
# 46  [Thiamine pyrophosphokinase (EC 2.7.7.2) isolated from dry brewing yeast has been purified 20-fold with a 70% yield, Certain properties of the enzyme have been determined: pH and temperature optim...
# 47  [The procedure for isolating aminoacyl-tRNA-synthetases from yeast Candida utilis IBPM-405 was developed, The rate of activation of L-amino acids in the formation of hydroxamates was different, As...
# 48  [We have examined three mutants of Klebsiella aerogenes whose genetic lesions (glnB, glnD, and glnE) are in loci unlinked to the structural gene for glutamine sythetase (glnA) and in which the con...
# 49  [The stability to heating and pH changing of two proteinases of Bacillus subtilis was studied, The preparations were: protosubtilin G10x with an activity of 21500 units/g and proteinase immobilize...
#
#                                                                                                                                                                                                entity pairs  \
# 0   [[Transductional  analysis, aeruginosa mutant PAO14], [mutant, HDH  content], [where  hnc-1, histidine locus biosynthesis], [at group IV which, structural  HDH], [genetic hnc-1 mutation, structura...
# 1   [[Bacteriocins, phage Rhizobium type], [molecular  weights, 1  X], [All, proteolytic protein enzymes], [They, DNAase], [six  bacteriocins, sensitive activity R], [, sensitive  bacteria], [Bacterio...
# 2   [[gamma haemolysin, Dolman Wilson cellophane], [haemolytic  ml, medium degrees pH], [crude  lysin, 75 % ultrafiltration], [active  precipitate, ammonium sulphate], [Purified gamma lysin, disc elec...
# 3   [[Arginine, Aspergillus nidulans mycelium], [single uptake system, arginine], [Transport, basic amino acids], [12  Ki, ornithine], [wt  transport, azide], [Neutral amnio acids, specifically methio...
# 4   [[respectively access ability, 90  min], [Aphids, virus], [Transmission, nonpersistent  viruses], [, well KCl concentration], [which, ml  TMV], [, ], [, ], [similar  mixture, transmission], [, ], ...
# 5   [[It, structural Vi polysaccharide], [liquid  method, phage deacetylase activity], [Purified  particles, plaque deacetylase activity], [They, also electron microscope], [Osmotic  shock, still base...
# 6   [[authors, severe head injuries], [IVP, ], [repeatedly  response, induced  hypertension], [Most  patients, ], [correlation, reduced brain function], [correlation, CBF], [CSF lactate, cortical brai...
# 7                                                                                                                                                                            [[who, special Health theory]]
# 8   [[hepatic protein concentration, reduced  glutathione], [specific acid activity, TT], [significant  effect, total liver activities], [specific  activity, contrast], [when U-14C)-L leucine data, dp...
# 9   [[TTP, 30  actomyosin], [effects, lesser  TDP], [important  differences, myosin TTPase], [Myosin TTPase, larger  ATPase], [TTP, greatly myosin B TTPase], [accelerating  effect, catalytically activ...
# 10  [[effects, isolated rat heart], [Hearts, 5 Ringer bicarbonate ml], [effect, ml-1 14C NA], [treated  hearts, 14C  NA], [degree, increasing  pancuronium], [combination, greater pancuronium factor], ...
# 11  [[, ], [Electrical  activities, sucrose gap technique], [, ], [like  which, going plateau type potential], [97 tension changes, spontaneous action potentials], [, ], [Tetrodotoxin, H2 receptor act...
# 12  [[internal  pH, sensitive crab muscle electrodes], [internal  pH, electrode  penetration], [mean membrane potential, mean], [, mean], [internal fibre pH, passively fibre membrane], [, ], [internal...
# 13  [[Oviducal  fluid, slaughtered  cows], [proteins, polyacrylamide gel pH], [small serum amounts, following gel filtration], [Small  amounts, oestrous migrating samples], [glycosidase levels, serum]...
# 14  [[1  week, 10 sperm weeks], [daily sperm output, seven sperm ejaculates], [Mean  concentrations, X6 week frequency], [Sperm output Sperm week, X6 week frequency], [Sperm output Sperm week, less X1...
# 15  [[high degrees obligoglycines, high degrees AppA], [then carboxyl group, pA], [solid  ImpA, imidazole  pA], [Next carboxyl group, situ], [subsequent  reactions, activated  pA], [good  yields, glyc...
# 16  [[Comparative  data, vertebrate Bohr hemoglobins], [phylogeny, hemoglobin vertebrates], [deoxy  dimer, single amino acid substitution], [deoxy  dimer, reduced oxygen monomer], [deoxy  which, oxyge...
# 17  [[Imidazole  catalysis, biochemical hydroxyl tRNA], [catalyzed  transfer, to  7.7], [10  %, phenylalanyl poly(U], [double  helix, poly(A  poly(U], [remainder, phenylalanine], [peptides, hydroxyl p...
# 18  [[three step treatment plan, spontaneous leukemia lymphoma], [Leukemic  mice, cytoreduction], [immunosuppressed AKR mice, immunocompetent  H-2], [combination cells, RF allogeneic hematopoiesis], [...
# 19  [[infected, infected glucose cultures], [red cell deterioration, when herpes simplex virus], [irradiated host HVT, functional cell replication], [inactivation, multihit host cell kinetics], [other...
# 20  [[50 degrees %, 1  days], [solution, 13 mug days], [When  203Hg2, 1 basal salt days], [, more  chemisorption], [following  factors, fiber glass fiber mercury], [Rubber, organic  mercury], [pH, cri...
# 21  [[properties, ethylenediaminetetraacetic Ringer solution], [1  sec, sarcolemmal slwo conductance increase], [which, physiological  range], [sarcolemmal conductance increase, rather Ringer solution...
# 22  [[study, healthy  man], [Eight  men, Hg  normoxia], [Anaerobic  samples, two hour intervals], [plasma pH, 2.5 mEq], [significant  changes, 12 H+ hr], [total acid excretion, mEq  control], [urinary...
# 23  [[isoglaucon instillation, markedly fellow eye], [Isoglaucon, uveal  tract], [hours angle 23, 9.3  +], [regularly  Isoglaucon, 0.10 outflow facility 0.20], [secretion, +  /-], [Isoglaucon, aqueous...
# 24  [[53 forest they, 70 tundra degrees], [borne  agents, CE California virus], [several Culiseta all, 13 degrees C], [, transovarial  transfer], [Principal vertebrate reservoirs, especially  hares], ...
# 25  [[nucleocapsid, 34 % RNA], [particle, 38  nm], [6.4  it, 32 nm state], [similar  contraction, however RNase RNA], [capsid mM SDS which, strong RNA protein interaction], [S value, 100  S], [Electro...
# 26  [[rheumatic disease syndromes, viral  hepatitis], [Twenty nine Twenty patients, sometimes  rash], [Ten  patients, multisystem disease], [Histologic evidence, ten multisystem disease], [Liver tissu...
# 27  [[, ], [, ], [Rhodomicrobium vanniellii, ethanol], [highest  amount, lower  Rh], [, ], [, ], [acidophila, methanol], [, Alcohol Rh], [, ], [Rhodospirillum rubrum, Rhodomicrobium Rh], [acidophila, ...
# 28                                                          [[, to Mycobacterium 11.5], [6.0  rate, 8.0  11.5], [8.0  rate, 9.0  11.0], [121  biosynthesis, to  8.2], [Changes, molecular  polysaccharide]]
# 29                              [[Chitinolytic  microorganisms, gypsy moth Trichophyton rubrum mycelia], [few, isolates], [, ], [, live  T], [rubrum, mycolytic carbon ability], [stable  that, N mycelia]]
# 30  [[elicit guinea pig effect, catecholamine release], [, morphine], [Pretreatemnt, significantly pressure threshold], [, ], [administration, untreated kg dl controls], [mg  kg, even  morphine], [Phe...
# 31  [[[ pyridine pyridine which, medium prestimulatory change], [KO alpha acid, slowly NAD(P)H fluorescence trace], [which, also fluorescence decrease], [KIV keto acid, significant insulin secretion],...
# 32  [[growth factor growth subunit, high QAE Sephadex], [acid NGF activity, intrinsic  dissociation], [Continued  exposure, isoelectric NGF point], [two  species, major isoelectric focusing], [three  ...
# 33  [[peptide growth factor chains, COOH terminal arginine residues], [carboxypeptidase chains, terminal arginine residues], [Exposure, arginine M containing], [amount, random  monomers], [Hybrid beta...
# 34  [[effects, cardiovascular  systems], [venous  blood, immediately study period], [initial ritodrine dose, 15  minutes], [dose, uterine  activity], [infusion, 30  minutes], [, late postinfusion peri...
# 35  [[Jovian  plants, severe  organisms], [such  challenge, ammonia], [efficient  effect, well  concentration], [effects, high  concentration], [Escherichia, extremely Bacillus ammonia], [aerobic  org...
# 36  [[GGTP Gamma activity, developing portacaval animals], [histochemical  techniques, liver tissue], [GGTP  activity, adult 2.0], [fetal enzyme activity, postnatal  day], [Then  values, postnatal adu...
# 37  [[Mucocutaneous lymph node syndrome, 5  days], [Additional  features, coronary  arteries], [, elevated serium IgE], [MCLS  which, polyarteritis infants], [acute IgE levels, same  Japan], [most  su...
# 38  [[Lung slices, 2 novo phospholipid], [less  activity, pH  7.6], [alkali rate that, pH], [predominantly lung lecithin demonstration, respiratory distress syndrome], [pH pathway effects, lecithin  s...
# 39                                           [[ATPase, HCO 3 HCO ions], [rabbit which, normally  HCO], [HCO 3 ATPase, plasma membrane marker], [activities, HCO 3 duct epithelium], [ATPase, 3  transport]]
# 40  [[ventilatory  responses, two doxapram hypothermia], [normothermic  KCN, minute  ventilations], [minute  ventilations, proportionally  normothermia], [Bolus infusions, normothermia degrees hypothe...
# 41                [[ventilatory  responses, anesthetized doxapram normothermia], [0.098  PaCO2, 9.7  mm], [0.034  f, VE], [, increased Bolus VE], [f, 18.0  %], [normal body reaction, respiratory  drive]]
# 42                                                                                                                                                                   [[DbetaH rat DP, dependent DbetaH DA]]
# 43  [[molecular  mechanism, molecular Bohr Perutz], [Bohr effect, oxy globin molecule], [Carbon dioxide, 4 carbamino compounds], [carbaminoformation, deoxygenated  haemoglobin], [heme  O2, carbamino c...
# 44                                                                                                          [[affinity, 2 DPG acidosis], [2 DPG effect, contrary], [Authors, continuous O2 administration]]
# 45  [[purpose, enzymic cell grain], [effect, enzymes], [, connection], [, ], [total  activity, pH cell values], [activity, different acidity levels], [optimum, cytolytic hemicellulase Tr], [, 5.6  Asp...
# 46  [[Thiamine pyrophosphokinase, 70 % yield], [Certain  properties, pH cocarboxylase biosynthesis], [+  rate, enzymic  reaction], [change, pH ion activator], [neopyrithiamin, enzymic  reaction], [Thi...
# 47  [[IBPM-405, tRNA  yeast], [rate, L amino hydroxamates], [Aspartic  acid, highest phenyl activation], [activation, alanine], [ATP  amount, protein mg], [hydroxamate formation, heavy chloromercury i...
# 48             [[glnA glutamine control, glutamine synthetase], [mutation, glutamate ammonia ligase], [greatly glutamine inability, high glutamine production], [adenylylated glutamine synthetase, glnA.]]
# 49  [[stability, two Bacillus subtilis], [preparations, 3880 protosubtilin units], [G10x, pH  optimum], [100 % activity, immobilized  preparation], [difference, more temperature minimum], [immobilized...
#
#                                                                                                                                                                                                   relations
# 0                                                                                                                                            [applied to, utilize, carried, marker, are in full, suggested]
# 1                                                                                                                         [found, ranged from, were of, were resistant, separated into, trifolii, occurred]
# 2                                                                                                                                            [produced on, obtained within, purified, was, was homogeneous]
# 3                                                                                                [investigated, is responsible, is, is, inhibited by, transported by, isolated as resistant, has unchanged]
# 4                                 [lost within, were able, seems similar, ratio of, was best, wt, 120000, favoured, wt, substituted for, wt, was necessary, favoured, remained aphid, show, suggest, ruled]
# 5                                                                                           [shown that, developed, exposed to, inspected under, found, exhibited, fractionated, showed, with, X, found in]
# 6                                       [measured regional, Hg, measured, reduced, found between average, found between, elevated, had, referred to, found in, increased in, provoked by induced, appeared]
# 7                                                                                                                                                                                                 [enhance]
# 8                                                                                                                               [fed to, was, found on, increased, reduced, existed, was, decreased, found]
# 9                                                                                                                                    [accelerated, observed in, was able, inhibited by, inhibited, suggest]
# 10                                                                       [evaluated, removed from, determined by, contained less, increased with, blocked, determined after, alter, caused, seen, been due]
# 11  [1, recorded with, 2, exhibited spontaneous, produced by spontaneous, 3, had, concluded, 4, was, sec, of mean, 5, increased whereas, 6, studied, was, increased with, were, 7, had, increased, range...
# 12                                                                                              [measured, S.E, mV, of, been, 2, tended, of, is, 3, had, 4, caused, was dependent, returned, 5, slykes, of]
# 13                                                                                                                           [collected by, examined by polyacrylamide, were, detected, revealed, elevated]
# 14                                                                                                                              [required, spermatozoa, were higher, was, was, raised, were higher, be, be]
# 15                                                                                                                                     [evaporated, believe, formed, activated by, leads to, obtained from]
# 16                                                                         [reviewed for vertebrate, deduced, proposed, has, resulted in, preceded, required, was, caused, been, were present, occurred in]
# 17                                                                                                                           [investigated as, increases from, transferred to, was, were, groups at, model]
# 18                                                                                                                                            [used, treated with, donors, killed with, treated, be useful]
# 19                                                                                                                        [displayed, showed, demonstrated, displayed, photoreactivated in chick, indicate]
# 20                                                                                                                         [adsorbed to, observed, decreased to, were, examined, was, was, show, concluded]
# 21                                                                                                        [investigated, required for maximum, suggested, was, inferred, increase, occurred, compared with]
# 22                                                                                                  [examines, hypoxia, studied at, fell with, observed within, was, accompanied, was negligible, conclude]
# 23                                                                                                                          [decrease, demonstrated, Hg, 0.01 to, decreased from, decrease after, produced]
# 24                                                                                                                                     [are prevalent, been, comprise several, Isolation of, are, detected]
# 25                                                                                                             [composed of, is spherical, undergoes, effected by, Treatment of, remains, showed irregular]
# 26                         [observed, manifested, seen with, was present, showed morphologic, detected in, were present, became, was present, was depressed, decreased in, decreased in, responded in, had]
# 27             [palustris, viridis, grow on, utilized by, palustris, Rh, accumulates, dehydrogenase of, palustris, viridis, is active, dehydrogenase from, is active, dehydrogenase of, is active, vary in]
# 28                                                                                                                                                   [lacticolum, is highest, is highest, lacticolum, have]
# 29                                                                                                                 [screened for, were mycolytic, mycelia, Supernatants from, showed, revealed exocellular]
# 30                                                                        [studied, confirmed, reduced, i.v, established, decreased, inhibited, influenced, reduced, rejected, in, support, norepinephrine]
# 31                                                                                                                                              [induced, started, caused, had, enhance, raised, concluded]
# 32                                                                                                                             [isolated by, has, resulted in, isolated by, had, was, decreased, determine]
# 33                                                                   [is, produced, resulted in, was close, formed from, has, decreased above, determined by, suggest, derived, was, decreased, had little]
# 34                                                                                                        [evaluated in, obtained for, was, increased by, maintained for, was, was, increased during, rose]
# 35                                                                                                           [have, arises from, is, studied, coli, is, found in, measured in, is, coli, support, suggests]
# 36                                                                               [studied in, used, was low, 20 on, declined, 69 to, corresponded to, showed, was low, began, increase of GGTP, correlated]
# 37                                                                                                                                          [is, include, is, is likely, studied along, indicate, appeared]
# 38                                                                                                                                                              [incubated, observed, found, are, suggests]
# 39                                                                                                                      [found in main, found in, localized in, increased in metabolic, involved in active]
# 40                                                                                                        [studied in anesthetized, evoked significant, were, elicited larger, augmented, was, demonstrate]
# 41                                                                                                                     [studied in anesthetized, Hg, resulted in, injections of, increased by, demonstrate]
# 42                                                                                                                                                                                              [decreases]
# 43                                                                                                          [explained according, is due, binds to, depends upon, lowered, compounds, binds to, lowers, is]
# 44                                                                                                                                                                          [depends on, is slow, verified]
# 45                                                                             [was, investigated, activity, e, measured, determined at different, was at, roseum at, niger at, enzymes of, showed, roseum]
# 46                                                                                                                          [purified, determined, studied, investigated, shown, transformed into thiamine]
# 47                                                                                                                       [utilis, was different, underwent, was insignificant, shown, inhibited by, showed]
# 48                                                                                                                                                                  [examined, alters, decreases, indicate]
# 49                                                                                                                             [studied, were, was, found at pH, was, was, was, activated at, activated at]

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

# %%
relations = flatten(sent_tokenized_eval_data['relations'].tolist())
entity_pairs = flatten(sent_tokenized_eval_data['entity pairs'].tolist())

# %%
source = [i[0] for i in entity_pairs]

target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
# [i for i in relations if i!='']

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=='is'], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.7) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=='applied to'], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(6, 6))
pos = nx.spring_layout(G, k = 0.7)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
